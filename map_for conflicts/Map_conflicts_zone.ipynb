# %%
# import pandas as pd
# import plotly.graph_objects as go
# import pandas as pd
# import geopandas as gpd
# import plotly.express as px
# import matplotlib.pyplot as plt

# new_dataset = pd.read_csv("/home/adzavon/Documents/Regression _machine_learning/Deep learning/conflict_dataset_1.csv")
# geojson_map = gpd.read_file("/home/adzavon/Documents/MSC_Data_Analysis/study area maping/regions.geojson")
# shapefile = gpd.read_file("/home/adzavon/Documents/MSC_Data_Analysis/study area maping/gadm36_BFA_shp/gadm36_BFA_shp/gadm36_BFA_1.shp")

# new_dataset['Region'] = new_dataset['Region'].replace(['Hauts-Bassins'], 'Haut-Bassins')
# new_dataset['Region'] = new_dataset['Region'].replace(['sahel'], 'Sahel')
# new_dataset['Region'] = new_dataset['Region'].replace(['boucle du Mouhoun'], 'Boucle du Mouhoun')

# shapefile_map = shapefile[["NAME_1","geometry"]]

# merged = shapefile_map.merge(new_dataset, left_on = "NAME_1", right_on = "Region")

# merged

# merged = shapefile_map.set_index('NAME_1').join(conflicts_dataset.set_index("EVENT_TYPE"))
# #merged_file = merged[["Year","EVENT_TYPE","SUM_CONFLICTS","geometry"]]
# # merged.head(2)
# # new = merged_file.rename_axis("Regions")
# # new.groupby(["Year","Regions","EVENT_TYPE"]).sum()
# # new
# conflicts_dataset = conflicts_dataset.groupby(["Year","Region","EVENT_TYPE"]).sum()
# #merged
# conflicts_dataset.to_csv("conflict_dataset.csv")
# #merged = shapefile_map.set_index('NAME_1').join(conflicts_dataset.set_index("EVENT_TYPE"))

# new_dataset = pd.read_csv("/home/adzavon/Documents/Regression _machine_learning/Deep learning/conflict_dataset_1.csv")
# #new_dataset.to_csv("/home/adzavon/Documents/Regression _machine_learning/Deep learning/conflict_dataset_1.csv")
# new_dataset['Region'] = new_dataset['Region'].replace(['Hauts-Bassins'], 'Haut-Bassins')

# merged = shapefile_map.merge(new_dataset, left_on = "NAME_1", right_on = "Region")
# merged

# %%
# fig = px.choropleth(merged, geojson=merged.geometry, 
#                     locations=merged.index, color="SUM_CONFLICTS",
#                     height=500,
#                    color_continuous_scale="Viridis")
# fig.update_geos(fitbounds="locations", visible=True)
# fig.update_layout(
#     title_text='Map'
# )
# fig.update(layout = dict(title=dict(x=0.5)))
# fig.update_layout(
#     margin={"r":0,"t":30,"l":10,"b":10},
#     coloraxis_colorbar={
#         'title':'Sum'})
# fig.show()

# %%
# # conflicts_dataset.groupby(["Year","Region","EVENT_TYPE"]).sum()

# fig, ax = plt.subplots(1, figsize=(10,6))
# merged_file.plot(column='SUM_CONFLICTS', cmap='Blues', linewidth=1, ax=ax, edgecolor='0.9', legend = True)
# ax.axis('off')

# %%
# import pandas as pd

# dataset = pd.read_excel("/home/adzavon/Documents/MSC_Data_Analysis/conflicts/conflicts_data_with_dates_2018_2022.xlsx")
# dataset

# %%
# import datetime as dt
# dataset["EVENT_DATE"] = pd.to_datetime(dataset["EVENT_DATE"], utc=True)
# dataset["Year"] = dataset["EVENT_DATE"].dt.year

# dataset = dataset[["Year","EVENT_DATE","ADMIN1","EVENT_TYPE"]]
# new_dataset = pd.get_dummies(dataset,columns=["EVENT_TYPE"])

# %%
# new_dataset.groupby(["Year","ADMIN1"]).sum().to_csv("conflicts_by_year_in_columns.csv")

# %%
# import the dataset
import geopandas as gpd
import json, io
import pandas as pd
import plotly.express as px

conflict_data = pd.read_csv("/home/adzavon/Documents/Regression _machine_learning/Deep learning/conflicts_by_regions_in_columns.csv")
shapefile = gpd.read_file("/home/adzavon/Documents/MSC_Data_Analysis/study area maping/gadm36_BFA_shp/gadm36_BFA_shp/gadm36_BFA_1.shp")
shapefile_sum = shapefile[["NAME_1","geometry"]]
regions_geojson = json.load(open('/home/adzavon/Documents/MSC_Data_Analysis/study area maping/regions.geojson'))

gdf = gpd.GeoDataFrame.from_features(regions_geojson.json()["features"], crs="4326")
# rename the incorrect name in my file

conflict_data['Region'] = conflict_data['Region'].replace(['Hauts-Bassins'], 'Haut-Bassins')
conflict_data['Region'] = conflict_data['Region'].replace(['sahel'], 'Sahel')
conflict_data['Region'] = conflict_data['Region'].replace(['boucle du Mouhoun'], 'Boucle du Mouhoun')

# merge shapefile and csv

merged = shapefile_sum.merge(conflict_data, left_on = "NAME_1", right_on = "Region")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_7475/3753136141.py in <module>
#      10 regions_geojson = json.load(open('/home/adzavon/Documents/MSC_Data_Analysis/study area maping/regions.geojson'))
#      11
# ---> 12 gdf = gpd.GeoDataFrame.from_features(regions_geojson.json()["features"], crs="4326")
#      13 # rename the incorrect name in my file
#      14
#
# AttributeError: 'dict' object has no attribute 'json'

# %%
fig = px.choropleth(merged, geojson=merged.geometry, 
                    locations=merged.index, color="Violence against civilians",
                    height=500,
                   color_continuous_scale="Reds")
fig.update_geos(fitbounds="locations", visible=True)
fig.update_layout(
    title_text='Map',
    mapbox={
            "style": "open-street-map",
            "zoom": 5,
            "layers": [
                {
                    "source": json.loads(gdf.geometry.to_json()),
                    "below": "traces",
                    "type": "line",
                    "color": "purple",
                    "line": {"width": 1.5},
                }
            ],
        },
        margin={"l": 0, "r": 0, "t": 0, "b": 0}
)
fig.update(layout = dict(title=dict(x=0.5)))
fig.update_layout(
    margin={"r":0,"t":30,"l":10,"b":10},
    coloraxis_colorbar={
        'title':'Sum'})
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7475/139775363.py in <module>
#      11             "layers": [
#      12                 {
# ---> 13                     "source": json.loads(gdf.geometry.to_json()),
#      14                     "below": "traces",
#      15                     "type": "line",
#
# NameError: name 'gdf' is not defined

# %%
# import the dataset
import geopandas as gpd

conflict_data = pd.read_csv("/home/adzavon/Documents/Regression _machine_learning/Deep learning/sum_conflicts_by_year_in_columns.csv")
shapefile = gpd.read_file("/home/adzavon/Documents/MSC_Data_Analysis/study area maping/gadm36_BFA_shp/gadm36_BFA_shp/gadm36_BFA_1.shp")
shapefile_sum = shapefile[["NAME_1","geometry"]]

# rename the incorrect name in my file

conflict_data['Region'] = conflict_data['Region'].replace(['Hauts-Bassins'], 'Haut-Bassins')
conflict_data['Region'] = conflict_data['Region'].replace(['sahel'], 'Sahel')
conflict_data['Region'] = conflict_data['Region'].replace(['boucle du Mouhoun'], 'Boucle du Mouhoun')

# merge shapefile and csv

merged = shapefile_map.merge(conflict_data, left_on = "NAME_1", right_on = "Region")
merged
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7475/3078378930.py in <module>
#      14 # merge shapefile and csv
#      15
# ---> 16 merged = shapefile_map.merge(conflict_data, left_on = "NAME_1", right_on = "Region")
#      17 merged
#
# NameError: name 'shapefile_map' is not defined

# %%
fig = px.choropleth(merged, geojson=merged.geometry, 
                    locations=merged.index, color="Violence against civilians",
                    height=500,
                   color_continuous_scale="Reds")
fig.update_geos(fitbounds="locations", visible=True)
fig.update_layout(
    title_text='Map'
)
fig.update(layout = dict(title=dict(x=0.5)))
fig.update_layout(
    margin={"r":0,"t":30,"l":10,"b":10},
    coloraxis_colorbar={
        'title':'Sum'})
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7475/2967593811.py in <module>
# ----> 1 fig = px.choropleth(merged, geojson=merged.geometry,
#       2                     locations=merged.index, color="Violence against civilians",
#       3                     height=500,
#       4                    color_continuous_scale="Reds")
#       5 fig.update_geos(fitbounds="locations", visible=True)
#
# NameError: name 'px' is not defined

# %%
import plotly.graph_objects as go
import pandas as pd


dataset = pd.read_csv("/home/adzavon/Documents/Regression _machine_learning/Deep learning/conflict_dataset_1.csv")
# dataset = dataset[["Year","ADMIN1","EVENT_TYPE","SUM_CONFLICTS"]]
# dataset = dataset.groupby(["Year","ADMIN1","EVENT_TYPE"]).sum()
dataset['Region'] = dataset['Region'].replace(['Hauts-Bassins'], 'Haut-Bassins')
dataset['Region'] = dataset['Region'].replace(['sahel'], 'Sahel')
dataset['Region'] = dataset['Region'].replace(['boucle du Mouhoun'], 'Boucle du Mouhoun')

# merge shapefile and csv

merged = shapefile_map.merge(dataset, left_on = "NAME_1", right_on = "Region")
simplify_merge = merged[["Year","Region","EVENT_TYPE","SUM_CONFLICTS","geometry"]]
simplify_merge.set_index("EVENT_TYPE")
simplify_merge
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7475/590558740.py in <module>
#      12 # merge shapefile and csv
#      13
# ---> 14 merged = shapefile_map.merge(dataset, left_on = "NAME_1", right_on = "Region")
#      15 simplify_merge = merged[["Year","Region","EVENT_TYPE","SUM_CONFLICTS","geometry"]]
#      16 simplify_merge.set_index("EVENT_TYPE")
#
# NameError: name 'shapefile_map' is not defined

# %%
# from dash import Dash, dcc, html, Input, Output
# import plotly.express as px
# import geopandas as gpd
# import pandas as pd
# import plotly.graph_objects as go

# dataset = pd.read_csv("/home/adzavon/Documents/Regression _machine_learning/Deep learning/conflict_dataset_1.csv")
# dataset['Region'] = dataset['Region'].replace(['Hauts-Bassins'], 'Haut-Bassins')
# dataset['Region'] = dataset['Region'].replace(['sahel'], 'Sahel')
# dataset['Region'] = dataset['Region'].replace(['boucle du Mouhoun'], 'Boucle du Mouhoun')

# # merge shapefile and csv
# shapefile = gpd.read_file("/home/adzavon/Documents/MSC_Data_Analysis/study area maping/gadm36_BFA_shp/gadm36_BFA_shp/gadm36_BFA_1.shp")
# shapefile_map = shapefile[["NAME_1","geometry"]]
# merged = shapefile_map.merge(dataset, left_on="NAME_1", right_on="Region")
# simplify_merge = merged[["Year","Region","EVENT_TYPE","SUM_CONFLICTS","geometry"]]
# shapefile.plot()
# app = Dash(__name__)

# app.layout = html.Div([
#     html.H4('Political candidate voting pool analysis'),
#     html.P("Select an event type:"),
#     dcc.RadioItems(
#         id='EVENT_TYPE', 
#         options=[{"label": "Battles", "value": "Battles"}, 
#                  {"label": "Explosions/Remote violence", "value": "Explosions/Remote violence"},
#                  {"label": "Protests", "value": "Protests"},
#                  {"label": "Riots", "value": "Riots"},
#                  {"label": "Strategic developments", "value": "Strategic developments"}],
#         value="Battles",
#     ),
#     html.P("Select a year:"),
#     dcc.RadioItems(
#         id='Year', 
#         options=[{"label": str(year), "value": year} for year in sorted(simplify_merge['Year'].unique())],
#         value=2018,
#     ),
#     dcc.Graph(id="graph1"),
#    # dcc.Graph(id ="graph2")
# ])

# @app.callback(
#     Output("graph1", "figure"),
#     #Output("graph2", "figure"),
#     Input("EVENT_TYPE", "value"),
#     Input("Year", "value"))
# def display_choropleth(event_type, year):
#     df = simplify_merge[(simplify_merge["EVENT_TYPE"] == event_type) & (simplify_merge["Year"] == year)]
#     fig2 = shapefile.plot()
#     fig1 = px.choropleth(df, geojson=df.geometry, 
#                     locations=df.index, 
#                     color="SUM_CONFLICTS",
#                     height=500,
#                     color_continuous_scale="Reds")
#     fig1.update_geos(fitbounds="locations")
# #     fig.update_layout(
# #         title_text='Map'
# #     )
#     fig1.update(layout = dict(title=dict(x=0.5)))
# #     fig.update_layout(
# #         margin={"r":0,"t":30,"l":10,"b":10},
# #         coloraxis_colorbar={
# #             'title':'Sum'})
   
#     return fig1, fig2

# if __name__ == '__main__':
#     app.run_server(debug=True, use_reloader=False)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__'
#  * Debug mode: on

# %%
from dash import Dash, dcc, html, Input, Output
import plotly.express as px
import geopandas as gpd
import pandas as pd




dataset = pd.read_csv("/home/adzavon/Documents/MSC_Data_Analysis/map_for conflicts/conflict_dataset_1.csv")
dataset['Region'] = dataset['Region'].replace(['Hauts-Bassins'], 'Haut-Bassins')
dataset['Region'] = dataset['Region'].replace(['sahel'], 'Sahel')
dataset['Region'] = dataset['Region'].replace(['boucle du Mouhoun'], 'Boucle du Mouhoun')

# merge shapefile and csv
shapefile = gpd.read_file("/home/adzavon/Documents/MSC_Data_Analysis/study area maping/gadm36_BFA_shp/gadm36_BFA_shp/gadm36_BFA_1.shp")
shapefile_map = shapefile[["NAME_1","geometry"]]
merged = shapefile_map.merge(dataset, left_on="NAME_1", right_on="Region")
simplify_merge_old = merged[["Year","Region","EVENT_TYPE","SUM_CONFLICTS","geometry"]]
simplify_merge = simplify_merge_old.set_index("Region")


app = Dash(__name__)

app.layout = html.Div([
    html.H4('Political candidate voting pool analysis'),
    html.P("Select an event type:"),
    dcc.RadioItems(
        id='EVENT_TYPE', 
        options=[{"label": "Battles", "value": "Battles"}, 
                 {"label": "Explosions/Remote violence", "value": "Explosions/Remote violence"},
                 {"label": "Protests", "value": "Protests"},
                 {"label": "Riots", "value": "Riots"},
                 {"label": "Strategic developments", "value": "Strategic developments"}],
        value="Battles",
    ),
    html.P("Select a year:"),
    
    dcc.RadioItems(
        id='Year', 
        options=[{"label": str(year), "value": year} for year in sorted(simplify_merge['Year'].unique())],
        value=2018,
    ),
    dcc.Graph(id="graph"),
])

@app.callback(
    Output("graph", "figure"),
    Input("EVENT_TYPE", "value"),
    Input("Year", "value"))
def display_choropleth(event_type, year):
    for index, types in enumerate(event_type):
        df = simplify_merge[(simplify_merge["EVENT_TYPE"] == event_type) & (simplify_merge["Year"] == year)]

        fig = px.choropleth_mapbox(df, geojson=df.geometry, 
                        locations=df.index, 
                        color="SUM_CONFLICTS",
                        color_continuous_scale="Reds",
                        range_color=(0, None),
                        mapbox_style="carto-positron",
                        zoom=5, center = {"lat": 12.2383, "lon": -1.5616},
                        opacity=1,
                        labels={'SUM_CONFLICTS':'Sum'})
        #fig.update_geos(fitbounds="locations")
        fig.update_geos(fitbounds="locations")
        fig.update_layout(
            title_text=f'Map of {event_type} for {year}'
        )
        fig.update_yaxes(type="log")
        fig.update_layout(
            margin={"r":0,"t":30,"l":10,"b":10},
            coloraxis_colorbar={
                'title':'Annual sum'})

    return fig

if __name__ == '__main__':
    app.run_server(debug=True, use_reloader=False)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__'
#  * Debug mode: on

# %%
# from dash import Dash, dcc, html, Input, Output
# import plotly.express as px
# import geopandas as gpd
# import pandas as pd
# import plotly.graph_objects as go

# dataset = pd.read_csv("/home/adzavon/Documents/Regression _machine_learning/Deep learning/conflict_dataset_1.csv")
# dataset['Region'] = dataset['Region'].replace(['Hauts-Bassins'], 'Haut-Bassins')
# dataset['Region'] = dataset['Region'].replace(['sahel'], 'Sahel')
# dataset['Region'] = dataset['Region'].replace(['boucle du Mouhoun'], 'Boucle du Mouhoun')

# # merge shapefile and csv
# shapefile = gpd.read_file("/home/adzavon/Documents/MSC_Data_Analysis/study area maping/gadm36_BFA_shp/gadm36_BFA_shp/gadm36_BFA_1.shp")
# shapefile_map = shapefile[["NAME_1","geometry"]]
# merged = shapefile_map.merge(dataset, left_on="NAME_1", right_on="Region")
# simplify_merge = merged[["Year","Region","EVENT_TYPE","SUM_CONFLICTS","geometry"]]

# event_types = simplify_merge['EVENT_TYPE'].unique()

# app = Dash(__name__)
# shapefile.plot()
# app.layout = html.Div([
#     html.H4('Political candidate voting pool analysis'),
    
#     html.P("Select a year:"),
#     dcc.RadioItems(
#         id='Year', 
#         options=[{"label": str(year), "value": year} for year in sorted(simplify_merge['Year'].unique())],
#         value=2018,
#     ),
    
#     html.Div([
#         html.Div([
#             dcc.Graph(id='graph_{}'.format(event_type), figure={})
#         ], className="six columns") for event_type in event_types
#     ], className="row")
# ])

# # Define list of event types
# event_types = ['Battles', 'Explosions/Remote violence', 'Protests', 'Riots', 'Strategic developments', 'Violence against civilians']

# # Define separate callbacks for each event type
# for event_type in event_types:
#     @app.callback(
#         Output(f"graph_{event_type}", "figure"),
#         Input("Year", "value"))
#     def display_choropleth(year):
        
#         df = simplify_merge[(simplify_merge["EVENT_TYPE"] == event_type) & (simplify_merge["Year"] == year)]

#         fig = px.choropleth_mapbox(df, geojson=df.geometry, 
#                         locations=df.index, 
#                         color="SUM_CONFLICTS",
#                         color_continuous_scale="Reds",
#                         range_color=(0, None),
#                         mapbox_style="carto-positron",
#                         zoom=5, center = {"lat": 12.2383, "lon": -1.5616},
#                         opacity=0.5,
#                         labels={'SUM_CONFLICTS':'Sum'})

#         fig.update_geos(fitbounds="locations")
#         fig.update_layout(
#             title_text=f'Map of {event_type} for {year}'
#         )
#         #fig.update_yaxes(type="log")
#         fig.update_layout(
#             margin={"r":0,"t":30,"l":10,"b":10},
#             coloraxis_colorbar={
#                 'title':'Sum'})

#         return fig


# if __name__ == '__main__':
#     app.run_server(debug=True, use_reloader=False)

# %%
# from dash import Dash, dcc, html, Input, Output
# import plotly.express as px
# import geopandas as gpd
# import pandas as pd
# import plotly.graph_objects as go

# # Read dataset
# dataset = pd.read_csv("/home/adzavon/Documents/Regression _machine_learning/Deep learning/conflict_dataset_1.csv")

# # Clean region names
# dataset['Region'] = dataset['Region'].replace(['Hauts-Bassins'], 'Haut-Bassins')
# dataset['Region'] = dataset['Region'].replace(['sahel'], 'Sahel')
# dataset['Region'] = dataset['Region'].replace(['boucle du Mouhoun'], 'Boucle du Mouhoun')

# # Read shapefile
# shapefile = gpd.read_file("/home/adzavon/Documents/MSC_Data_Analysis/study area maping/gadm36_BFA_shp/gadm36_BFA_shp/gadm36_BFA_1.shp")
# shapefile_map = shapefile[["NAME_1","geometry"]]

# # Merge shapefile and dataset
# merged = shapefile_map.merge(dataset, left_on="NAME_1", right_on="Region")
# simplify_merge = merged[["Year","Region","EVENT_TYPE","SUM_CONFLICTS","geometry"]]

# # Define list of event types
# event_types = simplify_merge['EVENT_TYPE'].unique()

# # Define app layout
# app = Dash(__name__)
# app.layout = html.Div([
#     html.H4('Spatial distribution on Conflict events by year'),
#     html.P("Select a year:"),
#     dcc.RadioItems(
#         id='Year', 
#         options=[{"label": str(year), "value": year} for year in sorted(simplify_merge['Year'].unique())],
#         value=2018,
#     ),
#     html.Div([
#         html.Div([
#             dcc.Graph(id='graph_{}'.format(event_type), figure={})
#         ],) for event_type in event_types
#     ], ),
# ])

# # Define separate callbacks for each event type
# for event_type in event_types:
#     @app.callback(
#         Output(f"graph_{event_type}", "figure"),
#         Input("Year", "value"))
#     def display_choropleth(year):
#         # Filter dataset by event type and year
#         df = simplify_merge[(simplify_merge["EVENT_TYPE"] == event_type) & (simplify_merge["Year"] == year)]
        
#         # Create choropleth map using Plotly Express
#         fig = px.choropleth_mapbox(df, geojson=df.geometry, 
#                         locations=df.index, 
#                         color="SUM_CONFLICTS",
#                         color_continuous_scale="Reds",
#                         range_color=(0, None),
#                         mapbox_style="carto-positron",
#                         zoom=5, center = {"lat": 12.2383, "lon": -1.5616},
#                         opacity=0.5,
#                         labels={'SUM_CONFLICTS':'Sum'})

#         fig.update_geos(fitbounds="locations")
#         fig.update_layout(
#             title_text=f'Map of {event_type} for {year}'
#         )
#         fig.update_layout(
#             margin={"r":0,"t":30,"l":10,"b":10},
#             coloraxis_colorbar={
#                 'title':'Sum'})

#         return fig

# # Run app
# if __name__ == '__main__':
#     app.run_server(debug=True, use_reloader=False)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__'
#  * Debug mode: on

# %%
# from dash import Dash, dcc, html, Input, Output
# import plotly.express as px
# import geopandas as gpd
# import pandas as pd
# import plotly.graph_objects as go

# # Read dataset
# dataset = pd.read_csv("/home/adzavon/Documents/Regression _machine_learning/Deep learning/conflict_dataset_1.csv")

# # Clean region names
# dataset['Region'] = dataset['Region'].replace(['Hauts-Bassins'], 'Haut-Bassins')
# dataset['Region'] = dataset['Region'].replace(['sahel'], 'Sahel')
# dataset['Region'] = dataset['Region'].replace(['boucle du Mouhoun'], 'Boucle du Mouhoun')

# # Read shapefile
# shapefile = gpd.read_file("/home/adzavon/Documents/MSC_Data_Analysis/study area maping/gadm36_BFA_shp/gadm36_BFA_shp/gadm36_BFA_1.shp")
# shapefile_map = shapefile[["NAME_1","geometry"]]

# # Merge shapefile and dataset
# merged = shapefile_map.merge(dataset, left_on="NAME_1", right_on="Region", right_index=False)

# simplify_merge = merged[["Year","Region","EVENT_TYPE","SUM_CONFLICTS","geometry"]]
# new = simplify_merge.set_index("Region")
# # Define list of event types
# # event_types = simplify_merge['EVENT_TYPE'].unique()
# # event_types
# fig = px.chloropleth(shapefile)
# fig.show
