# %%
import pandas as pd

# data = pd.read_excel("/home/adzavon/Desktop/situation-des-pdi-par-communes-31-octobre-2022pcodes - Copy.xlsx")
# data["Region"] = data.Region.str.lower()
# data.drop(columns=["Province","Commune"], inplace=True)
# data["Year"] = data["date"].dt.year
# data

# %%
# dataset = data.groupby(["Year","Region","montth",]).sum()
# dataset.to_excel("dataset.xlsx")
# pd.read_excel("dataset.xlsx")

# %%
conflicts_data = pd.read_excel("/home/adzavon/Documents/MSC_Data_Analysis/conflicts/conflicts.xlsx")
conflicts_data.columns
conflicts_data["EVENT_DATE"] = pd.to_datetime(conflicts_data["EVENT_DATE"]).dt.to_period('m')
conflicts_data["SUM_CONFLICTS"]=1
conflicts_data.to_excel("conflicts_data_with_dates_2018_2022.xlsx")
conflicts_data.dtypes
# Out:
# EVENT_DATE       period[M]
# ADMIN1              object
# EVENT_TYPE          object
# SUM_CONFLICTS        int64
# dtype: object

# %%
conflicts_data.groupby(["EVENT_DATE","ADMIN1","EVENT_TYPE"]).sum().to_excel("for map.xlsx")

# %%
conflicts_data.groupby(["ADMIN1","EVENT_TYPE"]).sum().to_excel("conflicts_per_event_type_2018_2022.xlsx")

# %%
# data_2 = data_1.drop(columns=["ISO","EVENT_ID_CNTY","EVENT_ID_NO_CNTY","TIME_PRECISION",'ASSOC_ACTOR_1', 'INTER1', 'ACTOR2', 'ASSOC_ACTOR_2', 'INTER2',
#        'INTERACTION','SOURCE',
#        'SOURCE_SCALE', 'NOTES', 'FATALITIES', 'TIMESTAMP',"GEO_PRECISION","REGION","YEAR",'ADMIN2', 'ADMIN3',
#        'LOCATION'
#        ])

# newdf = data_2.query('COUNTRY == "Burkina Faso"')



# #data_v = newdf.to_excel("conflicts.xlsx", index=False)

# work_data=newdf[["ADMIN1","LATITUDE","LONGITUDE","EVENT_DATE","ACTOR1","SUB_EVENT_TYPE","EVENT_TYPE"]]
# work_data

# %%
# #data_new_1 = pd.get_dummies(data = work_data, columns=["EVENT_TYPE"])
# work_data["Total_conflicts"] = 1
# # work_data["YEAR"] = work_data["EVENT_DATE"].dt.year
# # work_data["MONTH"] = work_data["EVENT_DATE"].dt.month

# #drrr = work_data[["EVENT_DATE","YEAR","MONTH","ADMIN1","LATITUDE","LONGITUDE","ACTOR1","SUB_EVENT_TYPE","EVENT_TYPE","Total_conflicts"]]

# drrr = work_data[["EVENT_DATE","ADMIN1","ACTOR1","EVENT_TYPE","Total_conflicts"]]
# drrr.to_excel("Try_conflicts.xlsx")

# conflicts_data = pd.read_excel("sum_conflicts.xlsx") 
# conflicts_data.groupby(["YEAR","MONTH","ADMIN1","EVENT_TYPE"]).sum().to_excel("sum_sum_conflicts.xlsx")

# %%
# #conflicts_data.groupby(["YEAR","MONTH","ADMIN1","EVENT_TYPE"]).sum().plot()
# conflicts_data.pivot_table('Total_conflicts', index='MONTH', columns='ADMIN1',aggfunc='sum').plot()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
rea_data = pd.read_excel("/home/adzavon/Documents/Regression _machine_learning/Simple_linear_regression/data_analysis/2018_2022_conflicts.xlsx")
rea_data.columns
# Out:
# Index(['YEAR', 'MONTH', 'ADMIN1', 'EVENT_TYPE', 'Total_conflicts'], dtype='object')

# %%
fig = go.Figure([go.Scatter(x=rea_data['YEAR'], y=rea_data['Total_conflicts'])])
fig.show()

# %%
import pandas as pd
import geopandas as gpd  
import datetime as dt
date = pd.read_excel("/home/adzavon/Documents/MSC_Data_Analysis/conflicts/conflicts_by_event.xlsx")
region = gpd.read_file("/home/adzavon/Documents/MSC_Data_Analysis/study area maping/gadm36_BFA_shp/gadm36_BFA_shp/gadm36_BFA_1.shp")
Region = region[["NAME_1","geometry"]].rename(columns={"NAME_1":"Region"})
# #date["Year"] = date["EVENT_DATE"].dt.year
# date["Year"] = pd.to_datetime(date["EVENT_DATE"]).dt.year
# date.to_excel("date_to_fill.xlsx")
# work_date = date[["EVENT_DATE","ADMIN1","EVENT_TYPE"]]
# work_date["Number_of_conflicts"]=1
# work_dat = work_date.groupby(["EVENT_DATE","ADMIN1","EVENT_TYPE",]).count().rename(columns={"ADMIN1":"Region"})
# #work_dat.to_excel("conflicts_Year_event_for map.xlsx")
# # merged = Region.set_index('Region').join(work_dat.set_index('ADMIN1'),inplace=True)
# # merged.head()
# work_dat

date["new_date"] = (date["Year"].astype(str))
new_date = date[["Year","Region","EVENT_TYPE","SUM_CONFLICTS"]]
new = new_date.groupby(["Year","Region","EVENT_TYPE"]).sum()
new
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
#date["Year"] = pd.to_datetime(date["Year"]).dt.year
merged = Region.set_index('Region').join(date.set_index('Region'))
merged.to_excel("Polygone_with_csv.xlsx")

# %%
# import matplotlib.pyplot as plt

# fig, ax = plt.subplots(1, figsize=(12, 12))
# ax.axis('off')
# ax.set_title('Paramedical Staffs at District Hospitals in India as of 31st March 2019',
#              fontdict={'fontsize': '15', 'fontweight' : '3'})
# fig = merged.plot(column='Year', cmap='RdYlGn', linewidth=0.5, ax=ax, edgecolor='0.2',legend=True)

# %%
import geopandas as gpd, pandas as pd
import json
import pandas as pd
import geoplot
import geoplot.crs as gcrs
import plotly.express as px
import matplotlib.pyplot as plt


regions_geojson = gpd.read_file(open('/home/adzavon/Documents/MSC_Data_Analysis/study area maping/regions.geojson'))


date = pd.read_excel("/home/adzavon/Documents/MSC_Data_Analysis/conflicts/conflicts_date_events_to_plot_on_map.xlsx")
# date.to_csv("let_stry.csv")
Try_again = pd.read_csv("/home/adzavon/Documents/MSC_Data_Analysis/conflicts/let_stry.csv", index_col=0)

# geoplot.polyplot(regions_geojson, projection=gcrs.AlbersEqualArea(), edgecolor='darkgrey', facecolor='lightgrey', linewidth=.3,
#     figsize=(12, 8))

# %%
fig = px.choropleth(Try_again, 
                    locations='Region',
                    geojson=regions_geojson,
                    color='EVENT_TYPE',
                    color_continuous_scale="Viridis",
                    scope= "africa",
                    

                          )
fig.update_geos(fitbounds="locations", visible=False)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_158554/2587702319.py in <module>
# ----> 1 fig = px.choropleth(Try_again,
#       2                     locations='Region',
#       3                     geojson=regions_geojson,
#       4                     color='EVENT_TYPE',
#       5                     color_continuous_scale="Viridis",
#
# NameError: name 'px' is not defined

# %%
import pandas as pd
import plotly.express as px
import json

with open("/home/adzavon/Documents/MSC_Data_Analysis/study area maping/regions.geojson", encoding='utf-8') as json_file:
    geojson = json.load(json_file)

df = pd.read_excel("/home/adzavon/Documents/MSC_Data_Analysis/conflicts/conflicts_by_event.xlsx")

# Checking that the data parameter is the same as the geojson parameter
# print(df["name-cz"][0])
# print(geojson["features"][0]["properties"]["name:cs"])



fig = px.choropleth_mapbox(new, 
                    locations='EVENT_TYPE',
                    geojson=geojson,
                    color='SUM_CONFLICT',
                    color_continuous_scale="Viridis",
                    # mapbox_style="carto-positron",
                    # zoom=7, center={"lat": 10.2, "lon": -1.5},
                    )

fig.update_layout(margin={"r": 0, "t": 0, "l": 0, "b": 0})

# fig.show()
# fig = px.choropleth(Try_again, 
#                     locations='Region',
#                     geojson=regions_geojson,
#                     color='EVENT_TYPE',
#                     color_continuous_scale="Viridis",
#                     scope= "africa",
                    

#                           )
# fig.update_geos(fitbounds="locations", visible=False)
# fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_158554/3283188829.py in <module>
#      14
#      15
# ---> 16 fig = px.choropleth_mapbox(new,
#      17                     locations='EVENT_TYPE',
#      18                     geojson=geojson,
#
# ~/anaconda3/lib/python3.9/site-packages/plotly/express/_chart_types.py in choropleth_mapbox(data_frame, geojson, featureidkey, locations, color, hover_name, hover_data, custom_data, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, opacity, zoom, center, mapbox_style, title, template, width, height)
#    1264     colored region on a Mapbox map.
#    1265     """
# -> 1266     return make_figure(args=locals(), constructor=go.Choroplethmapbox)
#    1267
#    1268
#
# ...
