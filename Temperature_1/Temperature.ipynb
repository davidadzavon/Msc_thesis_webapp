# %%
import pandas as pd

Temp_data = pd.read_excel("/home/adzavon/Documents/MSC_Data_Analysis/Temperature_1/All_temperature.xlsx")
Temp_data_na = Temp_data.dropna()

Temp_data_na.to_csv("/home/adzavon/Documents/MSC_Data_Analysis/Temperature_1/All_temperature.csv")

# %%
import pandas as pd

Temp_data = pd.read_excel("/home/adzavon/Documents/MSC_Data_Analysis/Precipitation/All_precipitation.xlsx")
Temp_data_na = Temp_data.dropna()

Temp_data_na.to_csv("/home/adzavon/Documents/MSC_Data_Analysis/Precipitation/All_precipitation.csv")

# %%
#Temp_data.pivot_table('Temperature', index='Date', columns='Location').plot()

# %%
import plotly.express as px

#px.line(Temp_data_na, x="Date", y="Temperature",  facet_col="Location", trendline="ols")

fig = px.scatter(Temp_data_na, x="Date", y="Temperature(°C)",              
                facet_col="Location",  
                #template = 'plotly_dark',
                trendline = 'ols',
                trendline_color_override='darkblue',
                #trendline_scope="overall",
                title = "Monthly Average Temperature for a representative climatique",
                
                )
fig.update_traces(mode='lines')#, line_color='blue'

# fig['data'][0]['line']['color']="red"
# fig['data'][1]['line']['color']="green"
# fig['data'][2]['line']['color']="green"
fig.show()

# %%
import plotly.graph_objects as go

trace1 = go.Scatter(
    x="Date",
    y="Temperature(°C)"
)
data = [trace1]
fig = go.Figure(data=Temp_data_na)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_15719/1928299742.py in <module>
#       1 import plotly.graph_objects as go
#       2
# ----> 3 trace1 = go.Scatter(
#       4     x="Date",
#       5     y="Temperature(°C)"
#
# ...

# %%
import pandas as pd

data = pd.read_csv("path", sep=",", header=None)
data.to_csv("path", sep=",")
